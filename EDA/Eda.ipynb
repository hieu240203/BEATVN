# %%
import sys
import os

sys.path.insert(1, "D:\BeatVn\Database")

# %%
import connect_database
import Get_database

# %%
conn = connect_database.connect_to_database()

# %%
Get_database.get_channel_data(conn)
# Out:
# Lấy thành công 654 bản ghi từ bảng Channel.
# D:\BeatVn\Database\Get_database.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#      IdChannel      TenChannel  NenTangId  HeCongDongId  HeSinhThaiId  \
# 0            1         YEAH1TV          2           NaN           2.0
# 1            2     YEAH1 MUSIC          2           NaN           2.0
# 2            3     YEAH1 MOVIE          2           NaN           2.0
# 3            4      YEAH1 SHOW          2           NaN           2.0
# 4            5      Yeah1 Kids          2           NaN           2.0
# ..         ...             ...        ...           ...           ...
# 649        650  Inside The Box          2          15.0           NaN
# 650        651        BEAT NOW          2          15.0           NaN
# ...

# %%
Get_database.get_post_data(conn)
# Out:
# Lấy thành công 21564 bản ghi từ bảng Post.
# D:\BeatVn\Database\Get_database.py:30: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#        IdPost  ChannelId                                            Content  \
# 0           1          1  Phim Kháng Nhật Mới Ra 2024 | NỘ HẢI HỒNG TRẦN...
# 1           2          1  Phim Kháng Nhật Mới Ra 2024 | NỘ HẢI HỒNG TRẦN...
# 2           3          1  Phim Kháng Nhật Mới Ra 2024 | NỘ HẢI HỒNG TRẦN...
# 3           4          1  Phim Kháng Nhật Mới Ra 2024 | NỘ HẢI HỒNG TRẦN...
# 4           5          1  Phim Kháng Nhật Mới Ra 2024 | NỘ HẢI HỒNG TRẦN...
# ...       ...        ...                                                ...
# 21559   22258        632  📣Official Teaser 1 - Bà Ngô Tường Vy, TGĐ Công...
# ...
